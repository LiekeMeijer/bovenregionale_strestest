# %%
from pathlib import Path
import geopandas as gpd
import shutil
from RA2CE_Run_functions_module import load_region_shapefile, load_networks, filter_network_by_region, create_segments_simple, move_output_file, copy_and_prepare_flood_map,process_Filter_flood_map_Ver02
from ra2ce.network.network_config_data.network_config_data import NetworkConfigData, NetworkSection, HazardSection
from ra2ce.network.network_config_data.enums.source_enum import SourceEnum
from ra2ce.network.network_config_data.enums.aggregate_wl_enum import AggregateWlEnum
from ra2ce.analysis.damages.damages import AnalysisSectionDamages
from ra2ce.analysis.analysis_config_data.enums.analysis_damages_enum import AnalysisDamagesEnum
from ra2ce.analysis.analysis_config_data.enums.event_type_enum import EventTypeEnum
from ra2ce.analysis.analysis_config_data.enums.damage_curve_enum import DamageCurveEnum
from ra2ce.analysis.analysis_config_data.analysis_config_data import AnalysisConfigData
from ra2ce.ra2ce_handler import Ra2ceHandler

# %%
region_list = ["Achterhoek", "Brabantse Delta",
               "Friesland","Groningen en NO-Drenthe","Limburg",
               "ARK-NZK", "Vallei en Veluwe", "Noord-Westelijke Delta", "Noord-Brabant Oost",
               "Rivierenland","Noord-Brabant Oost","Scheldestromen"
               ]

# %%
region_list = ["Overijsselse Vecht"
               ]

# %%
region_shapefile = Path(r"P:\bovenregionale-stresstest-hwn\Data\Hazard_maps\Gebiedsindeling obv waterschappen EXPORT 4dec24.gpkg")
HWN_network = Path(r"P:\bovenregionale-stresstest-hwn\Data\Shapes netwerkschakels\Shapes netwerkschakels\HWN_netwerkindeling.shp")
NWB_network = Path(r"P:\bovenregionale-stresstest-hwn\Data\Road_data\Rijkswegen_uit_nwb\rijkswegen.shp")

# %%
for region in region_list:
    print(f"Processing region: {region} hazard map")
    flood_map_folder = Path(rf"P:\bovenregionale-stresstest-hwn\Data\Hazard_maps\Uitlevering_BRS_compleet\{region}\Basisscenario\waterdiepte")
    flood_map_files = list(flood_map_folder.glob("*max_wd_merge_clipNL.tif")) + list(flood_map_folder.glob("*max_wd_merge_clipNL.tiff"))
    flood_duration_folder = Path(rf"P:\bovenregionale-stresstest-hwn\Data\Hazard_maps\Uitlevering_BRS_compleet\{region}\Basisscenario\Duur")
    Flood_duration_files = list(flood_duration_folder.glob("*duur_merge_clipNL.tif")) + list(flood_map_folder.glob("*duur_merge_clipNL.tiff"))
    
    if flood_map_files:
        flood_map_path = flood_map_files[0]
        print(f"Using flood map: {flood_map_path}")
    else:
        print("No TIFF files found in the folder.")
        
    if Flood_duration_files:
        flood_duration_path = Flood_duration_files[0]
        print(f"Using flood duration map: {flood_duration_path}")
    else:
        flood_duration_path = None
        print("No TIFF files found in the folder.")

    print("Processing networks - clipping to region and joining HWN and NWB networks")
    region_gdf, filtered_region = load_region_shapefile(region_shapefile, region)
    joined_network = load_networks(HWN_network, NWB_network)
    
    print(joined_network.columns)
    code = 'NWSCODE_HWN'  # This is what we use to clip ex: Networkschals inbetween regions should not be clipped
    filtered_network_gdf = filter_network_by_region(joined_network, filtered_region,code)
    
    print("Segmenting networks into 100m segments")
    print("Here we chose the NWB ID as the metric for segmenting the network into 100m segments.")
    segmentation_metric = 'id_NWB' #determine which metric to use for 100m segments
    segmented_gdfs = []
    grouped_networks = filtered_network_gdf.groupby(segmentation_metric)

    id_counter = 1
    for nwscode, group in grouped_networks:
        group_segments = []
        for idx, row in group.iterrows():
            segments_gdf = create_segments_simple(row.geometry, segment_length=100)
            for seg_idx, segment_row in segments_gdf.iterrows():
                new_row = row.copy()
                new_row.geometry = segment_row.geometry
                new_row['segment_id'] = f"{idx}_{seg_idx}"
                new_row['original_id'] = idx
                new_row['segment_number'] = seg_idx
                new_row['segment_length'] = segment_row.geometry.length
                new_row['highway'] = "motorway"
                new_row['lanes'] = 1
                new_row['REF_ID'] = id_counter 
                id_counter += 1  
                
                group_segments.append(new_row)
        if group_segments:
            group_gdf = gpd.GeoDataFrame(group_segments, crs=group.crs)
            segmented_gdfs.append(group_gdf)

    if segmented_gdfs:
        segmented_network_gdf = gpd.pd.concat(segmented_gdfs, ignore_index=True)
    else:
        segmented_network_gdf = filtered_network_gdf.copy()

    print("creating inputs for RA2CE run")
    region_dir = Path(rf"P:\bovenregionale-stresstest-hwn\Analysis\{region}")
    input_dir = region_dir.joinpath("Inputs")
    output_path = region_dir.joinpath("Outputs")
    static_path = input_dir.joinpath("static")
    overlay_path = static_path.joinpath("output_graph")
    network_path = static_path.joinpath("network")
    hazard_path = static_path.joinpath("hazard")
    
    

    for path in [region_dir, input_dir, static_path, network_path, hazard_path, output_path, output_path]:
        path.mkdir(parents=True, exist_ok=True)

    segmented_network_file = network_path.joinpath(f"{region}_segmented_network.gpkg")
    columns_to_drop = [col for col in segmented_network_gdf.columns if col.startswith('geometry_') and col != 'geometry']
    segmented_network_clean = segmented_network_gdf.drop(columns=columns_to_drop)
    segmented_network_clean.to_file(segmented_network_file)

    print("Preprocessing Flood Map")
    filtered_region_area = region_gdf[region_gdf['name'] == region]
    #copy_and_prepare_flood_map(flood_map_path, hazard_path, filtered_region_area, nodata_value=-9999)
    process_Filter_flood_map_Ver02(flood_map_path, hazard_path, filtered_region_area, nodata_value=-9999, threshold=0.01)
    if flood_duration_path:
        #copy_and_prepare_flood_map(flood_duration_path, hazard_path, filtered_region_area, nodata_value=-9999)
        process_Filter_flood_map_Ver02(flood_duration_path, hazard_path, filtered_region_area, nodata_value=-9999, threshold=0.01)

    
    all_maps = list(hazard_path.glob("*.tif"))
    print(all_maps)
    
    # So the flood depth map would always be processed first
    hazard_map = []

    # Add the 'merge' map first (required)
    merge_maps = [Path(file) for file in all_maps if "max_wd_merge" in file.name.lower()]
    if not merge_maps:
        raise FileNotFoundError("No hazard map with 'merge' in the filename was found.")
    hazard_map.append(merge_maps[0])  # Assuming only one merge map

    # Add the 'duur' map if it exists (optional)
    duur_maps = [Path(file) for file in all_maps if "duur" in file.name.lower()]
    if duur_maps:
        hazard_map.append(duur_maps[0]) 

    root_dir = input_dir
    network_section = NetworkSection(
        source=SourceEnum.SHAPEFILE,
        primary_file=[network_path.joinpath(f"{region}_segmented_network.gpkg")],
        file_id="REF_ID",
        link_type_column="highway",
        save_gpkg=True
    )

    hazard = HazardSection(
        hazard_map=hazard_map,
        aggregate_wl=AggregateWlEnum.MEAN,
        hazard_crs="EPSG:28992"
    )

    network_config_data = NetworkConfigData(
        root_path=root_dir,
        static_path=static_path,
        output_path=output_path,
        network=network_section,
        hazard=hazard
    )
    
    section_damage = [AnalysisSectionDamages(
    name='HZ_damage',
    analysis=AnalysisDamagesEnum.DAMAGES,
    event_type=EventTypeEnum.EVENT,
    damage_curve=DamageCurveEnum.HZ,
    save_gpkg=True,
    save_csv=True,
    )]
    
    analysis_config_data = AnalysisConfigData(analyses=section_damage, root_path=root_dir, output_path=output_path)
    analysis_config_data.input_path = root_dir.joinpath("input_data")

    print("Creating RA2CE handler and running analysis")
    handler = Ra2ceHandler.from_config(network_config_data, analysis_config_data)
    handler.configure()
    handler.run_analysis()

    move_output_file(overlay_path, output_path, "base_network_hazard.gpkg")
# Out:
# Processing region: Overijsselse Vecht hazard map
# Using flood map: P:\bovenregionale-stresstest-hwn\Data\Hazard_maps\Uitlevering_BRS_compleet\Overijsselse Vecht\Basisscenario\waterdiepte\OverijsselseVecht__max_wd_merge_clipNL.tif
# Using flood duration map: P:\bovenregionale-stresstest-hwn\Data\Hazard_maps\Uitlevering_BRS_compleet\Overijsselse Vecht\Basisscenario\Duur\OverijsselseVecht_duur_merge_clipNL.tif
# Processing networks - clipping to region and joining HWN and NWB networks
# HWN network columns:
# Index(['NWBVERSIE', 'NWBWVKID', 'NETWERKCAT', 'NWSCODE', 'NWSNAAM', 'STDLNR',
#        'STDLNAAM', 'STDLPOS', 'VKWNAAM', 'VKWCAT', 'VKWFUNCTIE', 'OBJNAAM',
#        'NWBWGNR', 'NWBWGDL', 'NWBHECTO', 'NWBRPE', 'NWBBST', 'NWBBKM',
#        'NWBEKM', 'NWBGME', 'NWBDISTR', 'NWBDIENST', 'NWBLENGTE', 'NWBWGAW',
#        'NWBWGHM', 'UPDATE', 'OBJECTID', 'LAST_UPDAT', 'SE_ANNO_CA',
#        'KNOOPPUNTT', 'NETWERKSCH', 'NETWERKS00', 'NETWERKS01', 'NETWERKS02',
#        'ST_LENGTH(', 'geometry'],
#       dtype='object')
# NWB network columns:
# Index(['id', 'SDE_ID', 'WVK_ID', 'WVK_BEGDAT', 'JTE_ID_BEG', 'JTE_ID_END',
#        'WEGBEHSRT', 'WEGNUMMER', 'WEGDEELLTR', 'HECTO_LTTR', 'BST_CODE',
#        'RPE_CODE', 'ADMRICHTNG', 'RIJRICHTNG', 'STT_NAAM', 'STT_BRON',
#        'WPSNAAM', 'GME_ID', 'GME_NAAM', 'HNRSTRLNKS', 'HNRSTRRHTS',
#        'E_HNR_LNKS', 'E_HNR_RHTS', 'L_HNR_LNKS', 'L_HNR_RHTS', 'BEGAFSTAND',
#        'ENDAFSTAND', 'BEGINKM', 'EINDKM', 'POS_TV_WOL', 'WEGBEHCODE',
#        'WEGBEHNAAM', 'DISTRCODE', 'DISTRNAAM', 'DIENSTCODE', 'DIENSTNAAM',
#        'WEGTYPE', 'WGTYPE_OMS', 'ROUTELTR', 'ROUTENR', 'ROUTELTR2', 'ROUTENR2',
#        'ROUTELTR3', 'ROUTENR3', 'ROUTELTR4', 'ROUTENR4', 'WEGNR_AW',
#        'WEGNR_HMP', 'GEOBRON_ID', 'GEOBRON_NM', 'BRONJAAR', 'OPENLR',
#        'BAG_ORL', 'FRC', 'FOW', 'ALT_NAAM', 'ALT_NR', 'REL_HOOGTE',
#        'geometry'],
#       dtype='object')
# Joined network columns:
# Index(['id_NWB', 'SDE_ID_NWB', 'WVK_ID', 'WVK_BEGDAT_NWB', 'JTE_ID_BEG_NWB',
#        'JTE_ID_END_NWB', 'WEGBEHSRT_NWB', 'WEGNUMMER_NWB', 'WEGDEELLTR_NWB',
#        'HECTO_LTTR_NWB', 'BST_CODE_NWB', 'RPE_CODE_NWB', 'ADMRICHTNG_NWB',
#        'RIJRICHTNG_NWB', 'STT_NAAM_NWB', 'STT_BRON_NWB', 'WPSNAAM_NWB',
#        'GME_ID_NWB', 'GME_NAAM_NWB', 'HNRSTRLNKS_NWB', 'HNRSTRRHTS_NWB',
#        'E_HNR_LNKS_NWB', 'E_HNR_RHTS_NWB', 'L_HNR_LNKS_NWB', 'L_HNR_RHTS_NWB',
#        'BEGAFSTAND_NWB', 'ENDAFSTAND_NWB', 'BEGINKM_NWB', 'EINDKM_NWB',
#        'POS_TV_WOL_NWB', 'WEGBEHCODE_NWB', 'WEGBEHNAAM_NWB', 'DISTRCODE_NWB',
#        'DISTRNAAM_NWB', 'DIENSTCODE_NWB', 'DIENSTNAAM_NWB', 'WEGTYPE_NWB',
#        'WGTYPE_OMS_NWB', 'ROUTELTR_NWB', 'ROUTENR_NWB', 'ROUTELTR2_NWB',
#        'ROUTENR2_NWB', 'ROUTELTR3_NWB', 'ROUTENR3_NWB', 'ROUTELTR4_NWB',
#        'ROUTENR4_NWB', 'WEGNR_AW_NWB', 'WEGNR_HMP_NWB', 'GEOBRON_ID_NWB',
#        'GEOBRON_NM_NWB', 'BRONJAAR_NWB', 'OPENLR_NWB', 'BAG_ORL_NWB',
#        'FRC_NWB', 'FOW_NWB', 'ALT_NAAM_NWB', 'ALT_NR_NWB', 'REL_HOOGTE_NWB',
#        'geometry_NWB', 'NWBVERSIE_HWN', 'NETWERKCAT_HWN', 'NWSCODE_HWN',
#        'NWSNAAM_HWN', 'STDLNR_HWN', 'STDLNAAM_HWN', 'STDLPOS_HWN',
#        'VKWNAAM_HWN', 'VKWCAT_HWN', 'VKWFUNCTIE_HWN', 'OBJNAAM_HWN',
#        'NWBWGNR_HWN', 'NWBWGDL_HWN', 'NWBHECTO_HWN', 'NWBRPE_HWN',
#        'NWBBST_HWN', 'NWBBKM_HWN', 'NWBEKM_HWN', 'NWBGME_HWN', 'NWBDISTR_HWN',
#        'NWBDIENST_HWN', 'NWBLENGTE_HWN', 'NWBWGAW_HWN', 'NWBWGHM_HWN',
#        'UPDATE_HWN', 'OBJECTID_HWN', 'LAST_UPDAT_HWN', 'SE_ANNO_CA_HWN',
#        'KNOOPPUNTT_HWN', 'NETWERKSCH_HWN', 'NETWERKS00_HWN', 'NETWERKS01_HWN',
#        'NETWERKS02_HWN', 'ST_LENGTH(_HWN', 'geometry_HWN', 'geometry',
#        'match'],
#       dtype='object')
# Index(['id_NWB', 'SDE_ID_NWB', 'WVK_ID', 'WVK_BEGDAT_NWB', 'JTE_ID_BEG_NWB',
#        'JTE_ID_END_NWB', 'WEGBEHSRT_NWB', 'WEGNUMMER_NWB', 'WEGDEELLTR_NWB',
#        'HECTO_LTTR_NWB', 'BST_CODE_NWB', 'RPE_CODE_NWB', 'ADMRICHTNG_NWB',
#        'RIJRICHTNG_NWB', 'STT_NAAM_NWB', 'STT_BRON_NWB', 'WPSNAAM_NWB',
#        'GME_ID_NWB', 'GME_NAAM_NWB', 'HNRSTRLNKS_NWB', 'HNRSTRRHTS_NWB',
#        'E_HNR_LNKS_NWB', 'E_HNR_RHTS_NWB', 'L_HNR_LNKS_NWB', 'L_HNR_RHTS_NWB',
#        'BEGAFSTAND_NWB', 'ENDAFSTAND_NWB', 'BEGINKM_NWB', 'EINDKM_NWB',
#        'POS_TV_WOL_NWB', 'WEGBEHCODE_NWB', 'WEGBEHNAAM_NWB', 'DISTRCODE_NWB',
#        'DISTRNAAM_NWB', 'DIENSTCODE_NWB', 'DIENSTNAAM_NWB', 'WEGTYPE_NWB',
#        'WGTYPE_OMS_NWB', 'ROUTELTR_NWB', 'ROUTENR_NWB', 'ROUTELTR2_NWB',
#        'ROUTENR2_NWB', 'ROUTELTR3_NWB', 'ROUTENR3_NWB', 'ROUTELTR4_NWB',
#        'ROUTENR4_NWB', 'WEGNR_AW_NWB', 'WEGNR_HMP_NWB', 'GEOBRON_ID_NWB',
#        'GEOBRON_NM_NWB', 'BRONJAAR_NWB', 'OPENLR_NWB', 'BAG_ORL_NWB',
#        'FRC_NWB', 'FOW_NWB', 'ALT_NAAM_NWB', 'ALT_NR_NWB', 'REL_HOOGTE_NWB',
#        'geometry_NWB', 'NWBVERSIE_HWN', 'NETWERKCAT_HWN', 'NWSCODE_HWN',
#        'NWSNAAM_HWN', 'STDLNR_HWN', 'STDLNAAM_HWN', 'STDLPOS_HWN',
#        'VKWNAAM_HWN', 'VKWCAT_HWN', 'VKWFUNCTIE_HWN', 'OBJNAAM_HWN',
#        'NWBWGNR_HWN', 'NWBWGDL_HWN', 'NWBHECTO_HWN', 'NWBRPE_HWN',
#        'NWBBST_HWN', 'NWBBKM_HWN', 'NWBEKM_HWN', 'NWBGME_HWN', 'NWBDISTR_HWN',
#        'NWBDIENST_HWN', 'NWBLENGTE_HWN', 'NWBWGAW_HWN', 'NWBWGHM_HWN',
#        'UPDATE_HWN', 'OBJECTID_HWN', 'LAST_UPDAT_HWN', 'SE_ANNO_CA_HWN',
#        'KNOOPPUNTT_HWN', 'NETWERKSCH_HWN', 'NETWERKS00_HWN', 'NETWERKS01_HWN',
#        'NETWERKS02_HWN', 'ST_LENGTH(_HWN', 'geometry_HWN', 'geometry',
#        'match'],
#       dtype='object')
# Segmenting networks into 100m segments
# Here we chose the NWB ID as the metric for segmenting the network into 100m segments.
# creating inputs for RA2CE run
# Preprocessing Flood Map
# Processed flood map saved to: P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\hazard\OverijsselseVecht__max_wd_merge_clipNL.tif
# Processed flood map saved to: P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\hazard\OverijsselseVecht_duur_merge_clipNL.tif
# [WindowsPath('P:/bovenregionale-stresstest-hwn/Analysis/Overijsselse Vecht/Inputs/static/hazard/OverijsselseVecht_duur_merge_clipNL.tif'), WindowsPath('P:/bovenregionale-stresstest-hwn/Analysis/Overijsselse Vecht/Inputs/static/hazard/OverijsselseVecht__max_wd_merge_clipNL.tif')]
# Creating RA2CE handler and running analysis
# 100%|██████████| 2002/2002 [00:00<00:00, 250081.80it/s]
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# 2025-10-22 10:47:05 AM - [avg_speed_calculator.py:176] - root - WARNING - No valid file found with average speeds P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\output_graph\avg_speed.csv, calculating and saving them instead.
# Graph hazard overlay with OverijsselseVecht__max_wd_merge_clipNL: 100%|██████████| 1004/1004 [01:00<00:00, 16.64it/s]
# Graph fraction with hazard overlay with OverijsselseVecht__max_wd_merge_clipNL: 100%|██████████| 1004/1004 [2:16:44<00:00,  8.17s/it]
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio\\_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\hazard\OverijsselseVecht_duur_merge_clipNL.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[18], line 144
#     142 print("Creating RA2CE handler and running analysis")
#     143 handler = Ra2ceHandler.from_config(network_config_data, analysis_config_data)
# --> 144 handler.configure()
#     145 handler.run_analysis()
#     147 move_output_file(overlay_path, output_path, "base_network_hazard.gpkg")
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\ra2ce_handler.py:162, in Ra2ceHandler.configure(self)
#     157 def configure(self) -> None:
#     158     """
#     159     Configures the `ConfigWrapper` with the current `AnalysisConfigData` and
#     160     `NetworkConfigData` so that the analyses can be succesfully run.
#     161     """
# --> 162     self.input_config.configure()
#     163     self.analysis_collection = AnalysisCollection.from_config(
#     164         self.input_config.analysis_config
#     165     )
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\configuration\config_wrapper.py:71, in ConfigWrapper.configure(self)
#      69 def configure(self) -> None:
#      70     if self.network_config:
# ---> 71         self.network_config.configure()
#      72     if self.analysis_config:
#      73         self.analysis_config.configure()
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\network_config_wrapper.py:85, in NetworkConfigWrapper.configure(self)
#      83 def configure(self) -> None:
#      84     self.configure_network()
# ---> 85     self.configure_hazard()
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\network_config_wrapper.py:103, in NetworkConfigWrapper.configure_hazard(self)
#     101 # There is a hazard map or multiple hazard maps that should be intersected with the graph.
#     102 hazard = HazardOverlay(self.config_data, self.graph_files)
# --> 103 self.graph_files = hazard.create()
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\hazard\hazard_overlay.py:531, in HazardOverlay.create(self)
#     526 #### Step 1: hazard overlay of the base graph (NetworkX) ###
#     527 if (
#     528     self.graph_files.base_graph.file
#     529     and not self.graph_files.base_graph_hazard.file
#     530 ):
# --> 531     self.graph_files.base_graph_hazard.graph = self._create_base_overlay(
#     532         self.graph_files.base_graph.get_graph()
#     533     )
#     535     self._export_network_files("base_graph_hazard", types_to_export)
#     537 #### Step 2: hazard overlay of the origins_destinations (NetworkX) ###
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\hazard\hazard_overlay.py:398, in HazardOverlay._create_base_overlay(self, base_graph)
#     393     # Assign the original geometries to the reprojected raster
#     394     return self.get_original_geoms_graph(
#     395         base_graph, _base_graph_hazard_reprojected
#     396     )
# --> 398 return self.hazard_intersect(base_graph)
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\hazard\hazard_overlay.py:314, in HazardOverlay.hazard_intersect(self, to_overlay)
#     307 # To improve performance we need to initialize the variables
#     308 if self.hazard_files.tif:
#     309     return HazardIntersectBuilderForTif(
#     310         hazard_aggregate_wl=self._hazard_aggregate_wl,
#     311         hazard_names=self.hazard_names,
#     312         ra2ce_names=self.ra2ce_names,
#     313         hazard_tif_files=self.hazard_files.tif,
# --> 314     ).get_intersection(to_overlay)
#     315 elif self.hazard_files.gpkg:
#     316     return HazardIntersectBuilderForGpkg(
#     317         hazard_field_name=self._hazard_field_name,
#     318         hazard_aggregate_wl=self._hazard_aggregate_wl,
#     319         ra2ce_names=self.ra2ce_names,
#     320         hazard_gpkg_files=self.hazard_files.gpkg,
#     321     ).get_intersection(to_overlay)
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\hazard\hazard_intersect\hazard_intersect_builder_base.py:39, in HazardIntersectBuilderBase.get_intersection(self, hazard_overlay)
#      37     return self._from_geodataframe(hazard_overlay)
#      38 elif isinstance(hazard_overlay, Graph):
# ---> 39     return self._from_networkx(hazard_overlay)
#      40 raise ValueError(
#      41     "No hazard intersection can be built with overlay type {}.".format(
#      42         type(hazard_overlay).__name__
#      43     )
#      44 )
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\hazard\hazard_intersect\hazard_intersect_builder_for_tif.py:162, in HazardIntersectBuilderForTif._from_networkx(self, hazard_overlay)
#     153     graph_fraction_flooded = graph_fraction_flooded.fillna(0)
#     154     set_edge_attributes(
#     155         hazard_overlay,
#     156         {
#    (...)    159         },
#     160     )
# --> 162 self._overlay_hazard_files(overlay_network_x)
#     163 return hazard_overlay
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\hazard\hazard_intersect\hazard_intersect_builder_for_tif.py:235, in HazardIntersectBuilderForTif._overlay_hazard_files(self, overlay_func)
#     233 def _overlay_hazard_files(self, overlay_func: Callable[[str, str, str], None]):
#     234     for i, (hn, rn) in enumerate(self._combined_names):
# --> 235         overlay_func(self.hazard_tif_files[i], hn, rn)
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\hazard\hazard_intersect\hazard_intersect_builder_for_tif.py:88, in HazardIntersectBuilderForTif._from_networkx.<locals>.overlay_network_x(hazard_tif_file, hazard_name, ra2ce_name)
#      86 def overlay_network_x(hazard_tif_file: Path, hazard_name: str, ra2ce_name: str):
#      87     # Check if the hazard and graph extents overlap
# ---> 88     validate_extent_graph(extent_graph, hazard_tif_file)
#      89     # Add a no-data value for the edges that do not have a geometry
#      90     set_edge_attributes(
#      91         hazard_overlay,
#      92         {
#    (...)     96         },
#      97     )
#
# File ~\Documents\GitHub\bovenregionale_strestest\ra2ce\network\hazard\hazard_common_functions.py:43, in validate_extent_graph(extent_graph, tif_hazard_file)
#      32 """
#      33 Validates the given extent graph to a hazard file (*.tif)
#      34
#    (...)     40     ValueError: When the hazard raster and the graph geometries do not overlap.
#      41 """
#      42 # Check if the hazard and graph extents overlap
# ---> 43 with rasterio.open(tif_hazard_file) as src:
#      44     # Get the bounding box
#      45     bounds = src.bounds
#      47 # Extract the extent
#
# File c:\SnapVolumesTemp\MountPoints\{45c63495-0000-0000-0000-100000000000}\{dd207255-f76a-4e73-8bed-3e64afdf945f}\SVROOT\envs\ra2ce_env_brs\Lib\site-packages\rasterio\env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File c:\SnapVolumesTemp\MountPoints\{45c63495-0000-0000-0000-100000000000}\{dd207255-f76a-4e73-8bed-3e64afdf945f}\SVROOT\envs\ra2ce_env_brs\Lib\site-packages\rasterio\__init__.py:368, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     365     path = _parse_path(raw_dataset_path)
#     367 if mode == "r":
# --> 368     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     369 elif mode == "r+":
#     370     dataset = get_writer_for_path(path, driver=driver)(
#     371         path, mode, driver=driver, sharing=sharing, **kwargs
#     372     )
#
# File rasterio\\_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: P:\bovenregionale-stresstest-hwn\Analysis\Overijsselse Vecht\Inputs\static\hazard\OverijsselseVecht_duur_merge_clipNL.tif: No such file or directory
